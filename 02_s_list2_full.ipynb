# %%
class Node:
    def __init__(self, v):
        self.value = v
        self.prev = None
        self.next = None

class LinkedList2:  
    def __init__(self):
        self.head = None
        self.tail = None
        
    def add_in_tail(self, item):
        if self.head is None:
            self.head = item
            item.prev = None
            item.next = None
        else:
            self.tail.next = item
            item.prev = self.tail
        self.tail = item
    
    def print_all_nodes(self):
        node = self.head
        while node is not None:
            print(node.value)
            node = node.next
            
    def find(self, val):
        node = self.head
        while node is not None:
            if node.value == val:
                return node
            node = node.next
        return None

    def find_all(self, val):
        node = self.head
        node_list = []
        while node is not None:
            if node.value == val:
                node_list.append(node)                
            node = node.next
        return node_list
    
    def delete (self, val, all=False):
        node = self.head
        if node is not None and node.value == val: 
            self.head = node.next
            if node.next is not None:
                self.head.prev = None #
            if node.next == None:
                self.tail = None
            if all == True:
                return self.delete(val, True)
            return
        
        while node is not None:
            if node.value == val:
                node.prev.next = node.next
                if node.next is not None:
                    node.next.prev = node.prev
                else:
                    self.tail = node.prev
                    self.tail.next = None
                if all == False:
                    return
            node = node.next
        
    def clean (self):
        self.head= None
        self.tail= None
        
    def len(self):
        node = self.head
        i = 0
        while node is not None:
            i+=1
            node=node.next
        return i
    
    def insert(self, afterNode, newNode):
        if afterNode == None:
            if self.head is None:
                self.head = newNode
                self.tail = self.head
            else:
                self.tail.next = newNode
                newNode.prev = self.tail
            self.tail = newNode
            return
                        
        node = self.head
        while node is not None:
            if node.next is not None and node == afterNode: 
                newNode.next = node.next
                node.next.prev = newNode
                node.next = newNode
                newNode.prev = node
                if node.next.next == None:
                    self.tail = node.next
                return
            elif node.next == None:
                self.tail = newNode
                self.tail.prev = node
                node.next = self.tail
                return
            node = node.next
            
    def add_in_head(self, newNode):
        if self.head is None:
            self.head = newNode
            newNode.prev = None
            newNode.next = None
            self.tail = self.head
        else:
            node = self.head
            self.head = newNode
            self.head.next = node
            node.prev = self.head  
            
    def make_list(self):
        list1 = []
        node = self.head
        while node is not None:
            list1.append(node.value)
            node = node.next
        return list1
    
    def make_list_reverse(self):
        list1 = []
        node = self.tail
        while node is not None:
            list1.append (node.value)
            node = node.prev
        return list1

# %%
ll = LinkedList2()
n = Node(0) ; ll.add_in_tail(n)
n = Node(0) ; ll.add_in_tail(n)
n = Node(1) ; ll.add_in_tail(n)
n = Node(1) ; ll.add_in_tail(n)
n = Node(1) ; ll.add_in_tail(n)
n = Node(2) ; ll.add_in_tail(n)
n = Node(2) ; ll.add_in_tail(n)

ll.delete(1) ; ll.delete(2) ; ll.delete(1)
ll.delete(2) ; ll.delete(1) ; ll.delete(0)

print(ll.head.next, ll.tail.next, ll.head.prev, ll.tail.prev)
print (ll.len())
print (ll.head == ll.tail)
# Out:
# None None None None
# 1
# True

# %%
# списки для тестирования
s_list_head = LinkedList2()
s_list_head.add_in_tail(Node(99))
s_list_head.add_in_tail(Node(1))
list = s_list_head.make_list()
print ('список', list, 'длина списка', s_list_head.len())

s_list_body = LinkedList2()
s_list_body.add_in_tail(Node(1))
s_list_body.add_in_tail(Node(99))
list_body = s_list_body.make_list()
print ('список', list_body, 'длина списка', s_list_body.len())
s_list_body.len()

s_list_body_head = LinkedList2()
s_list_body_head.add_in_tail(Node(99))
s_list_body_head.add_in_tail(Node(99))
list_body_head = s_list_body_head.make_list()
print ('список', list_body_head, 'длина списка', s_list_head.len())

s_list_none = LinkedList2()
s_list_none.add_in_tail(Node(999))
list_none = s_list_none.make_list()
print ('список', list_none, 'длина списка', s_list_none.len())

print ('-------------------------------------------------------')

print ('Тест удаления all = False')
for is_list in [s_list_head, s_list_body, s_list_body_head]:  #, s_list_none
    print ('Для списка', is_list.make_list())
    len_initial = 2
    is_list.delete(99, all = False)
    if is_list.find(99) is None:
        print ('Удаляемый узел отсутствует')
    else:
        print ('Удаляемый узел отсутствует')
    if is_list.len() == len_initial - 1:
        print ('Длина выдержана', 'До удаления', len_initial, 'После удаления', is_list.len())
    else:
        print ('Длина не выдержана', 'До удаления', len_initial, 'После удаления', is_list.len())
    if is_list.head == is_list.tail:
        print ('Голова и хвост на месте')
    else:
        print ('Голова', is_list.head, 'Хвост', is_list.tail)
    if is_list.head.next == None and is_list.tail.next == None and is_list.head.prev == None and is_list.tail.prev == None:
        print ('Голова и хвост указывают на None')
    else:
        print ('Голова или хвост указывают куда-то не туда')
    print ('-----------------------------------------------')
# Out:
# список [99, 1] длина списка 2
# список [1, 99] длина списка 2
# список [99, 99] длина списка 2
# список [999] длина списка 1
# -------------------------------------------------------
# Тест удаления all = False
# Для списка [99, 1]
# Удаляемый узел отсутствует
# Длина выдержана До удаления 2 После удаления 1
# Голова и хвост на месте
# Голова и хвост указывают на None
# -----------------------------------------------
# Для списка [1, 99]
# Удаляемый узел отсутствует
# Длина выдержана До удаления 2 После удаления 1
# Голова и хвост на месте
# Голова и хвост указывают на None
# -----------------------------------------------
# Для списка [99, 99]
# Удаляемый узел отсутствует
# Длина выдержана До удаления 2 После удаления 1
# Голова и хвост на месте
# Голова и хвост указывают на None
# -----------------------------------------------

# %%
# списки для тестирования
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(11))
s_list_one.add_in_tail(Node(99))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
s_list_set.add_in_tail(Node(12))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(25))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(35))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

print ('Тест удаления с тела all = False')
for is_list in [s_list, s_list_one, s_list_two, s_list_set]: 
    is_list.delete(99, all = False)
    list = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if 99 not in list:
        try:
            print ('Пройден', list, 'head',is_list.head.value, 'tail', is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
        except AttributeError:
            print ('Пройден', list, 'head',is_list.head, 'tail',is_list.tail, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)])
    else:
        print ('Провален', list, 'head',is_list.head.value, 'tail',is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# [1, 99, 55, 11, 128]
# []
# [11, 99]
# [1, 99, 55]
# [12, 99, 99, 25, 99, 99, 35, 99, 99, 132]
# Тест удаления с тела all = False
# Пройден [1, 55, 11, 128] head 1 tail 128 [128, 11, 55, 1] Листы равны True Указатели головы и хвоста None None
# Пройден [11] head 11 tail 11 [11] Листы равны True Указатели головы и хвоста None None
# Пройден [1, 55] head 1 tail 55 [55, 1] Листы равны True Указатели головы и хвоста None None
# Провален [12, 99, 25, 99, 99, 35, 99, 99, 132] head 12 tail 132 [132, 99, 99, 35, 99, 99, 25, 99, 12] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list = LinkedList2()
#s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(99))
#s_list_one.add_in_tail(Node(1))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
#s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
#s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(25))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(35))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
#s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

s_list_tail = LinkedList2()
s_list_tail.add_in_tail(Node(25))
s_list_tail.add_in_tail(Node(35))
s_list_tail.add_in_tail(Node(99))
list_tail = s_list_set.make_list()
print (list_set)

print ('Тест удаления с головы all = False')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set, s_list_tail]: 
    is_list.delete(99, all = False)
    list = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if 99 not in list:
        try:
            print ('Пройден', list, 'head',is_list.head.value, 'tail', is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
        except AttributeError:
            print ('Пройден', list, 'head',is_list.head, 'tail',is_list.tail, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)])
    else:
        print ('Провален', list, 'head',is_list.head.value, 'tail',is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# [99, 55, 11, 128]
# []
# [99]
# [99, 55]
# [99, 25, 99, 99, 35, 99, 99]
# [99, 25, 99, 99, 35, 99, 99]
# Тест удаления с головы all = False
# Пройден [55, 11, 128] head 55 tail 128 [128, 11, 55] Листы равны True Указатели головы и хвоста None None
# Пройден [] head None tail None [] Листы равны True
# Пройден [] head None tail None [] Листы равны True
# Пройден [55] head 55 tail 55 [55] Листы равны True Указатели головы и хвоста None None
# Провален [25, 99, 99, 35, 99, 99] head 25 tail 99 [99, 99, 35, 99, 99, 25] Листы равны True Указатели головы и хвоста None None
# Пройден [25, 35] head 25 tail 35 [35, 25] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(11))
s_list_one.add_in_tail(Node(99))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
s_list_set.add_in_tail(Node(12))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(25))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(35))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
#s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

print ('Тест удаления с тела all = True')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set]:
    is_list.delete(99, all = True)
    list = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if 99 not in list:
        try:
            print ('Пройден', list, 'head',is_list.head.value, 'tail', is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
        except AttributeError:
            print ('Пройден', list, 'head',is_list.head, 'tail',is_list.tail, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)])
    else:
        print ('Провален', list, 'head',is_list.head.value, 'tail',is_list.tail.value, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# [1, 99, 55, 11, 128]
# []
# [11, 99]
# [1, 99, 55]
# [12, 99, 99, 25, 99, 99, 35, 99, 99]
# Тест удаления с тела all = True
# Пройден [1, 55, 11, 128] head 1 tail 128 [128, 11, 55, 1] Листы равны True Указатели головы и хвоста None None
# Пройден [] head None tail None [] Листы равны True
# Пройден [11] head 11 tail 11 [11] Листы равны True Указатели головы и хвоста None None
# Пройден [1, 55] head 1 tail 55 [55, 1] Листы равны True Указатели головы и хвоста None None
# Пройден [12, 25, 35] head 12 tail 35 [35, 25, 12] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list = LinkedList2()
#s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(99))
#s_list_one.add_in_tail(Node(1))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
#s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
s_list_set.add_in_tail(Node(134))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(11))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(13))
s_list_set.add_in_tail(Node(17))
s_list_set.add_in_tail(Node(99))
#s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

print ('Тест удаления с головы all = True')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set]:
    is_list.delete(99, all = True)
    list = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if 99 not in list:
        try:
            print ('Пройден', list, 'head', is_list.head.value, 'tail',is_list.tail.value, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
        except AttributeError:
            print ('Пройден', list, 'head', is_list.head, 'tail',is_list.tail, list_rev, 'Листы равны', list == [x for x in reversed(list_rev)])
    else:
        print ('Провален', list)
# Out:
# [99, 55, 11, 128]
# []
# [99]
# [99, 55]
# [134, 99, 99, 99, 99, 11, 99, 99, 99, 13, 17, 99]
# Тест удаления с головы all = True
# Пройден [55, 11, 128] head 55 tail 128 [128, 11, 55] Листы равны True Указатели головы и хвоста None None
# Пройден [] head None tail None [] Листы равны True
# Пройден [] head None tail None [] Листы равны True
# Пройден [55] head 55 tail 55 [55] Листы равны True Указатели головы и хвоста None None
# Пройден [134, 11, 13, 17] head 134 tail 17 [17, 13, 11, 134] Листы равны True Указатели головы и хвоста None None

# %%
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)
print ('Тест insert_last')
for is_list in [s_list]:
    list_to_compare = is_list.make_list()
    list_to_compare.insert(5,666)
    is_list.insert (s_list.find(128), Node(666))
    list_inserted = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if list_inserted == list_to_compare:
        print ('Пройден', list_inserted, 'head', is_list.head.value , 'tail', is_list.tail.value, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
    else:
        print ('Провален', is_list.head, 'tail', is_list.tail, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# [1, 99, 55, 11, 128]
# Тест insert_last
# Пройден [1, 99, 55, 11, 128, 666] head 1 tail 666 [666, 128, 11, 55, 99, 1] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list_insert = LinkedList2()
s_list_insert.add_in_tail(Node(1))
s_list_insert.add_in_tail(Node(99))
s_list_insert.add_in_tail(Node(99))
s_list_insert.add_in_tail(Node(55))
s_list_insert.add_in_tail(Node(99))
s_list_insert.add_in_tail(Node(11))
s_list_insert.add_in_tail(Node(99))
s_list_insert.add_in_tail(Node(128))
list = s_list_insert.make_list()
print (list)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(99))
s_list.add_in_tail(Node(99))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
s_list.add_in_tail(Node(99))
list_two = s_list_two.make_list()
print (list_two)

print ('Тест insert')
for is_list in [s_list_insert, s_list_one, s_list_two]:
    list_to_compare = is_list.make_list()
    list_to_compare.insert(2, 666)
    is_list.insert (is_list.find(99), Node(666))
    list_inserted =  is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if list_inserted == list_to_compare:
        print ('Пройден', list_inserted, 'head', is_list.head.value , 'tail', is_list.tail.value, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
    else:
        print ('Провален',  list_inserted, 'head', is_list.head.value, 'tail', is_list.tail.value, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# [1, 99, 99, 55, 99, 11, 99, 128]
# [99]
# [1, 99, 55]
# Тест insert
# Пройден [1, 99, 666, 99, 55, 99, 11, 99, 128] head 1 tail 128 [128, 99, 11, 99, 55, 99, 666, 99, 1] Листы равны True Указатели головы и хвоста None None
# Пройден [99, 666] head 99 tail 666 [666, 99] Листы равны True Указатели головы и хвоста None None
# Пройден [1, 99, 666, 55] head 1 tail 55 [55, 666, 99, 1] Листы равны True Указатели головы и хвоста None None

# %%
s_list_empty = LinkedList2()
print ('Тест insert_empty')
for is_list in [s_list_empty]:
    list_to_compare = []
    list_to_compare.insert(0,666)
    is_list.insert (None, Node(666))
    list_inserted = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if list_inserted == list_to_compare:
        print ('Пройден', list_inserted, 'head', is_list.head.value , 'tail', is_list.tail.value, list_rev,list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
    else:
        print ('Провален', is_list.head, 'tail', is_list.tail, list_rev, list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)

        
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
print ('Тест insert_empty')
for is_list in [s_list]:
    list_to_compare = is_list.make_list()
    list_to_compare.insert(3,666)
    is_list.insert (None, Node(666))
    list_inserted = is_list.make_list()
    list_rev = is_list.make_list_reverse()
    if list_inserted == list_to_compare:
        print ('Пройден', list_inserted, 'head', is_list.head.value , 'tail', is_list.tail.value, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
    else:
        print ('Провален', is_list.head, 'tail', is_list.tail, list_rev, 'Листы равны', list_inserted == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# Тест insert_empty
# Пройден [666] head 666 tail 666 [666] True Указатели головы и хвоста None None
# Тест insert_empty
# Пройден [1, 99, 55, 666] head 1 tail 666 [666, 55, 99, 1] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list = LinkedList2()
#s_list.add_in_tail(Node(1))
#s_list.add_in_tail(Node(99))
#s_list.add_in_tail(Node(55))
#s_list.add_in_tail(Node(11))
#s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

print ("Тест добавить в голову")
s_list.add_in_head(Node(282))
test_list = s_list.make_list()
list_rev = s_list.make_list_reverse()
print (test_list, 'head', s_list.head.value, 'tail', s_list.tail.value, list_rev, 'Листы равны', test_list == [x for x in reversed(list_rev)], 'Указатели головы и хвоста', is_list.head.prev, is_list.tail.next)
# Out:
# []
# Тест добавить в голову
# [282] head 282 tail 282 [282] Листы равны True Указатели головы и хвоста None None

# %%
# списки для тестирования
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(11))
s_list_one.add_in_tail(Node(99))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
s_list_set.add_in_tail(Node(12))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(25))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(35))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

print ('Тест очистки')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set]:
    is_list.clean()
    list = is_list.make_list()
    if len(list)==0:
        print ('Пройден', list)
    else:
        print ('Провален', list)
# Out:
# [1, 99, 55, 11, 128]
# []
# [11, 99]
# [1, 99, 55]
# [12, 99, 99, 25, 99, 99, 35, 99, 99, 132]
# Тест очистки
# Пройден []
# Пройден []
# Пройден []
# Пройден []
# Пройден []

# %%
# списки для тестирования
s_list = LinkedList2()
s_list.add_in_tail(Node(1))
s_list.add_in_tail(Node(99))
s_list.add_in_tail(Node(55))
s_list.add_in_tail(Node(11))
s_list.add_in_tail(Node(128))
list = s_list.make_list()
print (list)

s_list_empty = LinkedList2()
s_list_empty.print_all_nodes()
list_empty = s_list_empty.make_list()
print (list_empty)

s_list_one = LinkedList2()
s_list_one.add_in_tail(Node(11))
s_list_one.add_in_tail(Node(99))
list_one = s_list_one.make_list()
print (list_one)

s_list_two = LinkedList2()
s_list_two.add_in_tail(Node(1))
s_list_two.add_in_tail(Node(99))
s_list_two.add_in_tail(Node(55))
list_two = s_list_two.make_list()
print (list_two)

s_list_set = LinkedList2()
s_list_set.add_in_tail(Node(12))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(25))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(35))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(99))
s_list_set.add_in_tail(Node(132))
list_set = s_list_set.make_list()
print (list_set)

print ('Тест find_all')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set]:
    list_found = is_list.find_all(99)
    list_to_compare =  [x for x in is_list.make_list() if x == 99]
    if list_found == list_to_compare:
        print ('Пройден', list_found)
    else:
        print ('Провален', list_found)
# Out:
# [1, 99, 55, 11, 128]
# []
# [11, 99]
# [1, 99, 55]
# [12, 99, 99, 25, 99, 99, 35, 99, 99, 132]
# Тест find_all
# Провален [<__main__.Node object at 0x0000024A59CCCC50>]
# Пройден []
# Провален [<__main__.Node object at 0x0000024A59CCCB38>]
# Провален [<__main__.Node object at 0x0000024A59CB9438>]
# Провален [<__main__.Node object at 0x0000024A59CB9DD8>, <__main__.Node object at 0x0000024A59CB9F28>, <__main__.Node object at 0x0000024A59CB94A8>, <__main__.Node object at 0x0000024A59CB9EB8>, <__main__.Node object at 0x0000024A59CB99B0>, <__main__.Node object at 0x0000024A59CB9240>]

# %%
print ('Тест len')
for is_list in [s_list, s_list_empty, s_list_one, s_list_two, s_list_set]:
    len_s_list = is_list.len()
    len_to_compare =  len(is_list.make_list())
    if len_s_list == len_to_compare:
        print ('Пройден', len_s_list)
    else:
        print ('Провален', len_s_list)
# Out:
# Тест len
# Пройден 5
# Пройден 0
# Пройден 2
# Пройден 3
# Пройден 10
